# %% [markdown]
# <img src="http://www.redttu.edu.co/es/wp-content/uploads/2016/01/itm.png" alt="drawing" width="400"/>
#
# <hr>
#
# Marcela Vallejo - 2019

# %% [markdown]
# <hr>
# # Development scheme of a data driven soft metrology system
# <br>
# <br>
# <font size=5>As shown in the following picture, the development process of data-driven soft metrology systems can be summarized in 4 stages:
# <br>
# <br>
# 1) database construction and pre-processing
# <br>
# <br>
# 2) generation of an effective representation space
# <br>
# <br>
# 3) model choice, training and validation
# <br>
# <br>
# 4) model maintenance. </font>
# <br>
# <br>
# <img src="pictures/development.jpg" alt="drawing" width="1000"/>
# <br>
# <br>
# <font size=5>In the book "Soft Sensors for Monitoring and Control of Industrial Processes", the following scheme is porposed:
# <br>
# <br>
# <img src="pictures/development2.png" />

# %% [markdown]
# <hr>
# # Database construction and preprocessing
# <br>
# <br>
# <img src="pictures/database contruction.jpg" />

# %% [markdown]
# <hr>
# # Critical analysis of available data
# <br>
# <br>
# <img src="pictures/critical_analysis.jpg"/>

# %% [markdown]
# <hr>
# # Normalization
# <br>
# <br>
# <font size=5>Data can have different magnitudes. Larger magnitude variables can become dominant over smaller ones during the identification process. Data scaling is needed. </font>
# <br>
# <br>
# <img src="pictures/normalization.jpg"/>
# <br>
# <br>
# <font size=5>The z-score normalization is preferred when large outliers are suspected because it is less sensitive to their presence.</font>
# <br>
# <br>

# %% [markdown]
# <hr>
# # Example datasets
# <br>
# <font size=5>We have a couple of example datasets we can use as a refernce in this course. Let´s examine each one </font>
# <br>
# <br>
# ## Debutanizer column
# <font size=5>In the following cell you will load and plot the data. Rememeber this dataset is composed by 7 inputs and one output.
# <br>
# <br>
# The debutanizer column is part of a desulfuring and naphtha splitter plant.
# <br>
# <br>
# In the debutanizer column C3 (propane) and C4 (butane) are removed as overheads from the naphtha stream.
# <br>
# <br>
# <img src="pictures/debutanizer.jpg"/>
# <br>
# <br>
# <font size=5>
# <br>
# <br>
# - A1, A2: Gas chromatographs
# <br>
# <br>
# - N1, N2: Required measure
# <br>
# <br>
# <br>
# The debutanizer column is required to:
# <br>
# <br>
# - Ensure sufficient fractionation in the debutanizer
# <br>
# <br>
# - Maximize the C5 (stabilized gasoline) content in the debutanizer overheads (LP gas splitter feed), while respecting the limit enforced by law
# <br>
# <br>
# - Minimize the C4 (butane) content in the debutanizer bottoms (Naphtha splitter feed)
# <br>
# <br>
# <br>
# <img src="pictures/debutanizer2.jpg"/>
# <br>
# <br>
# <br>
# <img src="pictures/debutanizer3.jpg"/>
# <br>
# <br>
# The purpose of modeling in the case considered was to obtain a very accurate dynamic model able to estimate the system output in real time, avoiding the long delay introduced by the analyzer, which in this case was estimated at about 45 min.
# <br>
# <br>
# The data were preprocessed in order to take into account the presence of missing and invalid data, recognized by the acquisition system and denoted as Out_of_Range.
# <br>
# <br>
# Data were acquired in different periods, with a sampling time Ts = 6 min.
# <br>
# <br>
# A set of about 2500 data values (normalized so as to avoid important variables whose magnitudes are small from being overshadowed by less important but larger magnitude variables), extracted from the plant historical database was considered.
# <br>
# <br>
# y values have been translated by 8 samples to compensate for the effect of the time delay.</font>
# <br>
# <br>
#
# ## Sulfur Recovery Unit
# <br>
# <br>
# <font size=5>The sulfur recovery unit (SRU) removes environmental pollutants from acid gas streams before they are released into the atmosphere. Furthermore, elemental sulfur is recovered as a valuable by-product.
# <br>
# <br>
# Hydrogen sulfide is particularly dangerous because it prevents the cells of the human body from breathing.
# <br>
# <br>
# <img src="pictures/SRU.jpg"/>
# <br>
# <br>
# - The SRU takes in two kinds of acid gases as input. The first, rich in H2S, called MEA gas, comes from the gas washing plants; the second, called SWS gas, rich in H2S and NH3 (ammonia), comes from the sour water stripping (SWS) plant.
# <br>
# <br>
# - Acid gases are burnt in reactors, where H2S is transformed into pure sulfur via a partial oxidation reaction with air. Gaseous combustion products from furnaces are cooled, causing the generation of liquid sulfur, which is collected in catch basins, and then passed through high temperature converters, where a further reaction leads to the formation of water vapor and sulfur.
# <br>
# <br>
# - The remaining, non converted gas (less than 5%), is fed to the Maxisulfur plant for a final conversion phase. The final gas stream (tail gas) from the SRU contains residual H2S and SO2.
# <br>
# <br>
# <img src="pictures/SRU2.jpg"/>
# <br>
# <br>
# - The main chamber is fed with MEA gas, and combustion is regulated, in air deficiency, by supplying an adequate air flow (AIR_MEA). The secondary combustion chamber is mainly fed with SWS gas and a suitable air flow is provided (AIR_SWS).
# <br>
# <br>
# - The combustion of SWS gas occurs in a separate chamber with excess air, in order to prevent the formation of ammonium salts in the equipment, thereby giving rise to the generation of nitrogen and nitrogen oxides. The gas input flow in the secondary chamber is kept constant by adding some MEA gas (MEA_SPILLING) when the SWS gas flow is too low. Thus, an adequate air flow is added (MEA_SPILLING_AIR). Air flows are controlled by plant operators to guarantee a correct stoichiometric ratio in the tail gas. Control is improved by a closed-loop algorithm which regulates a further air flow (AIR_MEA_2) on the basis of analysis of the tail gas composition.
# <br>
# <br>
# - Air, which supplies oxygen for the reaction, is an important parameter in the conversion of H2S, being responsible for the tail gas composition. In particular, an excessive air flow tends to increase the concentration of SO2 with respect to H2S, whereas a low air flow leads to the opposite situation.
# <br>
# <br>
# - On-line analyzers are used to measure the concentration of both hydrogen sulfide and sulfur dioxide in the tail gas of each sulfur line. The analyzers adopted are able to measure the quantity [H2S]-2[SO2] (where the brackets indicate concentration), in order to monitor the performance of the conversion process and control the air-to-feed ratio in the SRU with the aim of improving the sulfur extraction process.
# <br>
# <br>
# - Hydrogen sulfide and sulfur dioxide frequently cause damage to sensors, which often have to be removed for maintenance. The design of soft sensors able to predict H2S and SO2 concentrations is therefore required, as in the case study

# %% [markdown]
# <hr>
# # Example
# <br>
# <font size=5>Let's use the debutanizer data set. </font>
# <br>
# <br>
# <font size=5>In the following cell you will load and plot the data. Rememeber this dataset is composed by 7 inputs and one output.
# </font>
# <br>
# <br>

# %%
#importing necesary functions
import matplotlib.pyplot as plt
import numpy as np


#Loading the data
X=np.loadtxt('debutanizer_data.txt',skiprows=0, usecols=[0,1,2,3,4,5,6])
Y=np.loadtxt('debutanizer_data.txt',skiprows=0, usecols=[7])

plt.figure(figsize=(20, 10))
plt.subplot(2,4,1)

plt.plot(Y)

plt.title('salida',fontsize=20)

plt.subplot(2,4,2)

plt.plot(X[:,0])
plt.title('U1',fontsize=20)

plt.subplot(2,4,3)
plt.plot(X[:,1])
plt.title('U2',fontsize=20)

plt.subplot(2,4,4)
plt.plot(X[:,2])
plt.title('U3',fontsize=20)

plt.subplot(2,4,5)
plt.plot(X[:,3])
plt.title('U4',fontsize=20)

plt.subplot(2,4,6)
plt.plot(X[:,4])
plt.title('U5',fontsize=20)

plt.subplot(2,4,7)
plt.plot(X[:,5])
plt.title('U6',fontsize=20)

plt.subplot(2,4,8)
plt.plot(X[:,6])
plt.title('U7',fontsize=20)
plt.show()

# %% [markdown]
# # Remark
# <br>
# <font size=5>Have in mind that this dataset is already normalized to contain values between 0 and 1. </font>
# <br>
# <br>
# <font size=5>However, as we have seen, there are other types of normalization. Let's normalize data to obtain median 0 and std. deviation 1. In the next cell you can see such normalization
# </font>
# <br>
# <br>

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import preprocessing


yn=preprocessing.scale(Y)
xn=preprocessing.scale(X)


plt.figure(figsize=(20, 10))
plt.subplot(2,4,1)

plt.plot(yn)

plt.title('salida normalizada',fontsize=20)


plt.subplot(2,4,2)

plt.plot(xn[:,0])
plt.title('U1n',fontsize=20)

plt.subplot(2,4,3)
plt.plot(xn[:,1])
plt.title('U2n',fontsize=20)

plt.subplot(2,4,4)
plt.plot(xn[:,2])
plt.title('U3n',fontsize=20)

plt.subplot(2,4,5)
plt.plot(xn[:,3])
plt.title('U4n',fontsize=20)

plt.subplot(2,4,6)
plt.plot(xn[:,4])
plt.title('U5n',fontsize=20)

plt.subplot(2,4,7)
plt.plot(xn[:,5])
plt.title('U6n',fontsize=20)

plt.subplot(2,4,8)
plt.plot(xn[:,6])
plt.title('U7n',fontsize=20)
plt.show()

# %% [markdown]
# <hr>
# # Outliers
# <br>
# <font size=5>An outlier is a data point that differs significantly from other observations. They can represent a natural variation in the measurement or they can indicate experimental errors. If the cause is an error, they should be excluded from the data set. An outlier can cause serious problems in statistical analyses. </font>
# <br>
# <br>
# <img src="pictures/what_outlier.jpg"/>
# <br>
# <br>
# <font size=5>Let´s see an example.  </font>
# <br>
# <br>
# <img src="pictures/outlier_ex1.jpg"/>
# <br>
# <br>
# <img src="pictures/outlier_ex2.jpg"/>
# <br>
# <br>
# <font size=5>And what is the importance of the outliers?  </font>
# <br>
# <br>
# <img src="pictures/outlier_effect.jpg"/>
# <br>
# <br>
# <font size=5>So, if they are due to error in the measuring procces, they can cause severe problems with a model  </font>
# <br>
# <br>
# <img src="pictures/out-liars.jpg"/>
# <br>
# <br>
# <font size=5>But, how can I detect an outlier? </font>
# <br>
# <br>
# <img src="pictures/outlier_detection.jpg"/>
# <br>
# <br>

# %% [markdown]
# <hr>
# # Z-score
# <br>
# <font size=5>Simply put, a z-score is the number of standard deviations from the mean a data point is. A common practice  is to discard data that has a Z-score >3 </font>
# <br>
# <font size=5> It is important to consider that it asumes a normal distribution on the data.</font>
# <br>
# <br>
# <img src="pictures/zscore.jpg"/>
# <br>
# <br>
# <font size=5> In the following cell we will find outliers in yn using z-score.</font>
# <br>
# <br>

# %%
# Finding outliers with z-score in yn
from scipy import stats
import numpy as np
import matplotlib.pyplot as plt

#calculate z-score

z = np.abs(stats.zscore(yn))

# threshold of 3 std deviations to conider outlier
threshold = 3

# find outliers and save in a list
anomalies=[]
xanomalies=[]
i=0

for outlier in z:
        if outlier > 3:
            anomalies.append(yn[i])
            xanomalies.append(i)
        i=i+1

# plot data
plt.figure(figsize=(20, 10))
plt.plot(yn)

# Mark outliers
i=0
for j in anomalies:
    plt.plot([xanomalies[i]], [anomalies[i]],'bo')
    i=i+1
plt.show()

# %% [markdown]
# <br>
# <br>
# <font size=5> Now, lets do it in Y.</font>
# <br>
# <br>

# %%
# Finding outliers with z-score in yn
from scipy import stats
import numpy as np
import matplotlib.pyplot as plt

#calculate z-score

z = np.abs(stats.zscore(Y))

# threshold of 3 std deviations to conider outlier
threshold = 3

# find outliers and save in a list
anomalies=[]
xanomalies=[]
i=0

for outlier in z:
        if outlier > 3:
            anomalies.append(Y[i])
            xanomalies.append(i)
        i=i+1

# plot data
plt.figure(figsize=(20, 10))
plt.plot(Y)

# Mark outliers
i=0
for j in anomalies:
    plt.plot([xanomalies[i]], [anomalies[i]],'bo')
    i=i+1
plt.show()

# %% [markdown]
# <hr>
# # Quartiles
# <br>
# <font size=5>A different criterion is the use on interquartile range. Elements more than 1.5 interquartile ranges above the upper quartile or below the lower quartile. This method is useful when the data is not normally distributed. </font>
# <br>
# <br>
# <img src="pictures/interquartile.jpg"/>
# <br>
# <br>
# <font size=5>Let's find outliers in Y using this method. </font>
# <br>
# <br>

# %%
import seaborn as sns
import numpy as np
plt.figure(figsize=(20, 10))
sns.boxplot(Y)
Q1= np.percentile(Y, 25)  # Q1
Q3= np.percentile(Y, 75)  # Q3
IQR = Q3 - Q1
print(IQR)
anomalies=[]
xanomalies=[]
i=0
for j in Y:
    if (j < (Q1 - 1.5 * IQR)) or j > (Q3 + 1.5 * IQR):
        anomalies.append(Y[i])
        xanomalies.append(i) 
    i=i+1
plt.figure(figsize=(20, 10))
plt.plot(Y)

# Mark outliers
i=0
for j in anomalies:
    plt.plot([xanomalies[i]], [anomalies[i]],'bo')
    i=i+1
plt.show()
# Out:
# 0.14887345999999999

# %% [markdown]
# <br>
# <br>
# <font size=5>Now let´s do it with yn </font>
# <br>
# <br>

# %%
import seaborn as sns
import numpy as np
plt.figure(figsize=(20, 10))
sns.boxplot(yn)
Q1= np.percentile(yn, 25)  # Q1
Q3= np.percentile(yn, 75)  # Q3
IQR = Q3 - Q1
print(IQR)
anomalies=[]
xanomalies=[]
i=0
for j in yn:
    if (j < (Q1 - 1.5 * IQR)) or j > (Q3 + 1.5 * IQR):
        anomalies.append(yn[i])
        xanomalies.append(i) 
    i=i+1
plt.figure(figsize=(20, 10))
plt.plot(yn)

# Mark outliers
i=0
for j in anomalies:
    plt.plot([xanomalies[i]], [anomalies[i]],'bo')
    i=i+1
plt.show()
# Out:
# 0.9368408506176454

# %% [markdown]
# <hr>
# # Grubbs test
# <br>
# <font size=5>In statistics, Grubbs's test or the Grubbs test, also known as the maximum normalized residual test or extreme studentized deviate test, is a test used to detect outliers in a univariate data set assumed to come from a normally distributed population.That is, one should first verify that the data can be reasonably approximated by a normal distribution before applying the Grubbs test.
# <br>
# <br>
# Grubbs's test detects one outlier at a time. This outlier is expunged from the dataset and the test is iterated until no outliers are detected. However, multiple iterations change the probabilities of detection, and the test should not be used for sample sizes of six or fewer since it frequently tags most of the points as outliers.
# <br>
# <br>
# The porcedure is the following:
# <br>
# <br>
# Step 1: Order the data points from smallest to largest.
# <br>
# <br>
# Step 2: Find the mean (x̄) and standard deviation of the data set.
# <br>
# <br>
# Step 3: Calculate the G test statistic using one of the following equations: </font>
# <br>
# <br>
# <font size=5> <center>  $G = \frac{\displaystyle{\min_{1,...,N} } |Y_i-\bar{Y}|}{s}$
# <br>
# <br>
# <left>Where $\bar{Y}$ is the mean ann $s$ in the standar deviation
# <br>
# <br>
# A left-tailed test uses the test statistic:
# <br>
# <br>
# <font size=5> <center>  $G= \frac{\bar{Y} - Y_{min} }{s}$
# <br>
# <br>
# <left>Where $Y_{min}$ is the minimum value.
# <br>
# <br>
# For a right-tailed test, use:
# <br>
# <br>
# <font size=5> <center>  $G= \frac{Y_{max} -\bar{Y}}{s}$
# <left>
# <br>
# <br>
# <left>Where $Y_{max}$ is the maximum value.
# <br>
# <br>
#  Step 4: If the resulting test statistic G is greater than the critical value, the corresponding value can be regarded to be an outlier.
# <br>
# <br>
# <img src="pictures/grubs.jpg"/>

# %% [markdown]
# <br>
# <font size=5>First, we will have to install the library that will help us find outliers with grubbs test </font>
# <br>
# <br>

# %%
import sys
# !{sys.executable} --version
# !pip --version
# !python -m pip install --upgrade pip setuptools wheel
# Out:
# Python 2.7.15 :: Anaconda, Inc.
# pip 18.1 from /home/nbuser/anaconda2_501/lib/python2.7/site-packages/pip (python 2.7)
# ...
#     100% |████████████████████████████████| 1.4MB 2.6MB/s ta 0:00:011��          | 972kB 10.9MB/s eta 0:00:01
# Requirement already up-to-date: setuptools in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (41.0.1)
# ...
#   Using cached https://files.pythonhosted.org/packages/bb/10/44230dd6bf3563b8f227dbf344c908d412ad2ff48066476672f3a72e174e/wheel-0.33.4-py2.py3-none-any.whl
# ...
#   Found existing installation: pip 19.1.1
#     Uninstalling pip-19.1.1:
#       Successfully uninstalled pip-19.1.1
#   Found existing installation: wheel 0.32.3
#     Uninstalling wheel-0.32.3:
#       Successfully uninstalled wheel-0.32.3
# ...

# %% [markdown]
# <br>
# <font size=5>If we have pip installed an updated, we can porcedd with the installation </font>
# <br>

# %%
# !pip install "outlier_utils"
# Out:
# DEPRECATION: Python 2.7 will reach the end of its life on January 1st, 2020. Please upgrade your Python as Python 2.7 won't be maintained after that date. A future version of pip will drop support for Python 2.7. More details about Python 2 support in pip, can be found at https://pip.pypa.io/en/latest/development/release-process/#python-2-support
# ...

# %% [markdown]
# <br>
# <font size=5>Now we can use the outilers library </font>
# <br>

# %%
# import necesary libraries

from outliers import smirnov_grubbs as grubbs
import pandas as pd

#find outliers for left-tailed test
anomalies= grubbs.max_test_outliers(yn, alpha=0.05)
xanomalies= grubbs.max_test_indices(yn, alpha=0.05)

#plot data
plt.figure(figsize=(20, 10))
plt.plot(yn)

# Mark outliers
i=0
for j in anomalies:
    plt.plot([xanomalies[i]], [anomalies[i]],'bo')
    i=i+1

    
#find outliers for rigth-tailed test

anomalies= grubbs.min_test_outliers(yn, alpha=0.05)
xanomalies= grubbs.min_test_indices(yn, alpha=0.05)


# Mark outliers
i=0
for j in anomalies:
    plt.plot([xanomalies[i]], [anomalies[i]],'bo')
    i=i+1
    
plt.show()
